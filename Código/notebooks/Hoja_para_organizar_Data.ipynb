# %%
import pandas as pd

# %%
jjoo=pd.read_csv("data/athlete_events.csv")

# %%
jjoo.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
sorted(jjoo["Year"].unique())
# Out:
# [1896,
#  1900,
#  1904,
#  1906,
#  1908,
#  1912,
#  1920,
#  1924,
#  1928,
#  1932,
#  1936,
#  1948,
#  1952,
#  1956,
#  1960,
#  1964,
#  1968,
#  1972,
#  1976,
#  1980,
#  1984,
#  1988,
#  1992,
#  1994,
#  1996,
#  1998,
#  2000,
#  2002,
#  2004,
#  2006,
#  2008,
#  2010,
#  2012,
#  2014,
#  2016]

# %% [markdown]
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------

# %%
records=pd.read_csv("data/prueba2.txt",sep="\t")

# %%
records
# Out:
#            Event    Year           Athlete  Flag Country       Mark Record  \
# 0         100m M  2012.0        Usain Bolt   NaN     JAM       9.63     OR
# 1         100m M  2008.0        Usain Bolt   NaN     JAM       9.69     WR
# 2         100m M  1996.0    Donovan Bailey   NaN     CAN       9.84     WR
# 3         100m M  1988.0        Carl Lewis   NaN     USA       9.92     OR
# 4         100m M  1968.0         Jim Hines   NaN     USA       9.95     WR
# ..           ...     ...               ...   ...     ...        ...    ...
# 703  50km Walk M  1964.0      Abdon Pamich   NaN     ITA  4.11.12,4     WR
# 704  50km Walk M  1960.0   Donald Thompson   NaN     GBR  4.25.30,0     OR
# 705  50km Walk M  1952.0  Giuseppe Dordoni   NaN     ITA  4.28.07,8     OR
# 706  50km Walk M  1936.0   Harold Whitlock   NaN     GBR  4.30.41,4     OR
# 707  50km Walk M  1932.0      Thomas Green   NaN     GBR    4.50.10     OR
#
#      Round
# 0    Final
# 1    Final
# 2    Final
# 3    Final
# ...

# %%
records.drop("Flag",axis=1,inplace=True)

# %%
records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Event    708 non-null    object
#  1   Year     493 non-null    float64
#  2   Athlete  646 non-null    object
#  3   Country  708 non-null    object
#  4   Mark     708 non-null    object
#  5   Record   708 non-null    object
#  6   Round    708 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 38.8+ KB

# %%
records["Year"]=records["Year"].astype("object")

# %%
records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Event    708 non-null    object
#  1   Year     493 non-null    object
#  2   Athlete  646 non-null    object
#  3   Country  708 non-null    object
#  4   Mark     708 non-null    object
#  5   Record   708 non-null    object
#  6   Round    708 non-null    object
# dtypes: object(7)
# memory usage: 38.8+ KB

# %%
records["Year"].fillna(method="ffill",inplace=True)

# %%
records.iloc[290:302]
# Out:
#               Event    Year           Athlete Country   Mark Record  \
# 290  110m hurdles M  2004.0         Liu Xiang     CHN  12.91    EWR
# 291  110m hurdles M  1996.0     Allen Johnson     USA  12.95     OR
# 292  110m hurdles M  1988.0     Roger Kingdom     USA  12.98     OR
# 293  110m hurdles M  1988.0     Roger Kingdom     USA  13.17     OR
# 294  110m hurdles M  1984.0     Roger Kingdom     USA   13.2     OR
# 295  110m hurdles M  1984.0     Roger Kingdom     USA  13.24    EOR
# 296  110m hurdles M  1984.0       Greg Foster     USA  13.24    EOR
# 297  110m hurdles M  1984.0       Greg Foster     USA  13.24    EOR
# 298  110m hurdles M  1972.0    Rodney Milburn     USA  13.24    EWR
# 299  110m hurdles M  1968.0  Willie Davenport     USA   13.3     OR
# 300  110m hurdles M  1968.0        Ervin Hall     USA   13.3     OR
# 301  110m hurdles M  1968.0        Eddy Ottoz     ITA   13.5    EOR
#
#             Round
# 290         Final
# 291         Final
# 292         Final
# ...

# %%
records[records["Event"]=="Long Jump M"]
# Out:
#            Event    Year           Athlete Country  Mark Record  \
# 475  Long Jump M  1968.0        Bob Beamon     USA   8.9     WR
# 476  Long Jump M  1968.0      Ralph Boston     USA  8.27     OR
# 477  Long Jump M  1960.0      Ralph Boston     USA  8.12     OR
# 478  Long Jump M  1936.0       Jesse Owens     USA  8.06     OR
# 479  Long Jump M  1928.0       Edward Hamm     USA  7.73     OR
# 480  Long Jump M  1912.0  Albert Gutterson     USA   7.6     OR
# 481  Long Jump M  1908.0     Francis Irons     USA  7.48     OR
# 482  Long Jump M  1904.0   Meyer Prinstein     USA  7.34     OR
# 483  Long Jump M  1900.0  Alvin Kraenzlein     USA  7.18     OR
# 484  Long Jump M  1896.0      Ellery Clark     USA  6.35     OR
#
#                 Round
# 475             Final
# 476  Qualifying Round
# 477             Final
# 478             Final
# 479  Qualifying Round
# 480             Final
# 481             Final
# 482             Final
# 483             Final
# 484             Final

# %%
records.iloc[0]["Year"]
# Out:
# 2012.0

# %%
records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Event    708 non-null    object
#  1   Year     708 non-null    float64
#  2   Athlete  646 non-null    object
#  3   Country  708 non-null    object
#  4   Mark     708 non-null    object
#  5   Record   708 non-null    object
#  6   Round    708 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 38.8+ KB

# %%
records["Year"]=records["Year"].astype("int")

# %%
records["Year"].dtype
# Out:
# dtype('int32')

# %%
records.head(3)
# Out:
#     Event  Year         Athlete Country  Mark Record  Round
# 0  100m M  2012      Usain Bolt     JAM  9.63     OR  Final
# 1  100m M  2008      Usain Bolt     JAM  9.69     WR  Final
# 2  100m M  1996  Donovan Bailey     CAN  9.84     WR  Final

# %%
record_batido_misma_edicion=records.groupby(["Event","Year"])["Country"].value_counts()

# %%
record_batido_misma_edicion.sort_values(ascending=False)
#Aquí vemos que el record de 200M se batió 5 veces en 1968 (pero habrá que separar por tipo de record)
# Out:
# Event           Year  Country
# 200m M          1968  USA        5
# 100m M          1968  USA        5
# 100m hurdles W  1968  AUS        4
# 110m hurdles M  1984  USA        4
# 100m hurdles W  1956  AUS        4
#                                 ..
# 4x100m W        1952  USA        1
#                       AUS        1
#                 1936  GER        1
#                 1932  USA        1
# 5000m M         1932  FIN        1
# Name: Country, Length: 568, dtype: int64

# %%
records.to_csv("records.csv",index=False)
record_batido_misma_edicion.to_csv("record_batido_misma_edicion.csv",index=False)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# Desde aquí, hago la tabla de PIB totales

# %%
import pandas as pd

# %%
pib_total_1960=pd.read_csv("PIB/Total/1960.csv",sep=";")
pib_total_1964=pd.read_csv("PIB/Total/1964.csv",sep=";")
pib_total_1968=pd.read_csv("PIB/Total/1968.csv",sep=";")
pib_total_1972=pd.read_csv("PIB/Total/1972.csv",sep=";")
pib_total_1976=pd.read_csv("PIB/Total/1976.csv",sep=";")
pib_total_1980=pd.read_csv("PIB/Total/1980.csv",sep=";")
pib_total_1984=pd.read_csv("PIB/Total/1984.csv",sep=";")
pib_total_1988=pd.read_csv("PIB/Total/1988.csv",sep=";")
pib_total_1992=pd.read_csv("PIB/Total/1992.csv",sep=";")
pib_total_1996=pd.read_csv("PIB/Total/1996.csv",sep=";")
pib_total_2000=pd.read_csv("PIB/Total/2000.csv",sep=";")
pib_total_2004=pd.read_csv("PIB/Total/2004.csv",sep=";")
pib_total_2008=pd.read_csv("PIB/Total/2008.csv",sep=";")
pib_total_2012=pd.read_csv("PIB/Total/2012.csv",sep=";")
pib_total_2016=pd.read_csv("PIB/Total/2016.csv",sep=";")
pib_total_2021=pd.read_csv("PIB/Total/2021.csv",sep=";")

# %%
dfs_pib_totales=[pib_total_1960,pib_total_1964,pib_total_1968,pib_total_1972,pib_total_1976,
             pib_total_1980,pib_total_1984,pib_total_1988,pib_total_1992,pib_total_1996,
             pib_total_2000,pib_total_2004,pib_total_2008,pib_total_2012,pib_total_2016,
             pib_total_2021]
columnas_a_eliminar=["Unnamed: 3","Date","GDP Growth (%)"]
for i in dfs_pib_totales:
    i.drop(columns=columnas_a_eliminar,axis=1,inplace=True)
#pib_total_1960=pib_total_1960.drop(columns=columnas_a_eliminar,axis=1)

# %%
pib_total_1960=pib_total_1960.rename(columns={"Annual GDP":"1960"})
pib_total_1964=pib_total_1964.rename(columns={"Annual GDP":"1964"})
pib_total_1968=pib_total_1968.rename(columns={"Annual GDP":"1968"})
pib_total_1972=pib_total_1972.rename(columns={"Annual GDP":"1972"})
pib_total_1976=pib_total_1976.rename(columns={"Annual GDP":"1976"})
pib_total_1980=pib_total_1980.rename(columns={"Annual GDP":"1980"})
pib_total_1984=pib_total_1984.rename(columns={"Annual GDP":"1984"})
pib_total_1988=pib_total_1988.rename(columns={"Annual GDP":"1988"})
pib_total_1992=pib_total_1992.rename(columns={"Annual GDP":"1992"})
pib_total_1996=pib_total_1996.rename(columns={"Annual GDP":"1996"})
pib_total_2000=pib_total_2000.rename(columns={"Annual GDP":"2000"})
pib_total_2004=pib_total_2004.rename(columns={"Annual GDP":"2004"})
pib_total_2008=pib_total_2008.rename(columns={"Annual GDP":"2008"})
pib_total_2012=pib_total_2012.rename(columns={"Annual GDP":"2012"})
pib_total_2016=pib_total_2016.rename(columns={"Annual GDP":"2016"})
pib_total_2021=pib_total_2021.rename(columns={"Annual GDP":"2021"})

# %%
pib_total_1960 #Hasta aquí bien
# Out:
#                                 Countries       1960
# 0                       United States [+]  $542,400M
# 1                           Euro zone [+]  $244,833M
# 2                      United Kingdom [+]   $73,234M
# 3                             Germany [+]        NaN
# 4                              France [+]   $62,226M
# ..                                    ...        ...
# 103  Saint Vincent and the Grenadines [+]       $13M
# 104                         Venezuela [+]    $7,779M
# 105                      South Africa [+]    $8,749M
# 106                            Zambia [+]      $713M
# 107                          Zimbabwe [+]    $1,053M
#
# [108 rows x 2 columns]

# %%
dfs_pib_totales=[pib_total_1960,pib_total_1964,pib_total_1968,pib_total_1972,pib_total_1976,
             pib_total_1980,pib_total_1984,pib_total_1988,pib_total_1992,pib_total_1996,
             pib_total_2000,pib_total_2004,pib_total_2008,pib_total_2012,pib_total_2016,
             pib_total_2021]

pib_totales=pib_total_1960

# %%
pib_totales
# Out:
#                                 Countries       1960
# 0                       United States [+]  $542,400M
# 1                           Euro zone [+]  $244,833M
# 2                      United Kingdom [+]   $73,234M
# 3                             Germany [+]        NaN
# 4                              France [+]   $62,226M
# ..                                    ...        ...
# 103  Saint Vincent and the Grenadines [+]       $13M
# 104                         Venezuela [+]    $7,779M
# 105                      South Africa [+]    $8,749M
# 106                            Zambia [+]      $713M
# 107                          Zimbabwe [+]    $1,053M
#
# [108 rows x 2 columns]

# %%
dfs_pib_totales=[pib_total_1960,pib_total_1964,pib_total_1968,pib_total_1972,pib_total_1976,
             pib_total_1980,pib_total_1984,pib_total_1988,pib_total_1992,pib_total_1996,
             pib_total_2000,pib_total_2004,pib_total_2008,pib_total_2012,pib_total_2016,
             pib_total_2021]


for i in dfs_pib_totales[1:]:
    pib_totales=pd.merge(pib_totales,i,on="Countries",how="outer")

# %%
pib_totales
# Out:
#               Countries       1960       1964       1968         1972  \
# 0     United States [+]  $542,400M  $684,500M  $940,700M  $1,279,100M
# 1         Euro zone [+]  $244,833M  $373,024M  $518,992M    $879,867M
# 2    United Kingdom [+]   $73,234M   $94,408M  $107,760M    $169,965M
# 3           Germany [+]        NaN        NaN        NaN    $299,802M
# 4            France [+]   $62,226M   $94,008M  $129,785M    $203,494M
# ..                  ...        ...        ...        ...          ...
# 194      Tajikistan [+]        NaN        NaN        NaN          NaN
# 195     Timor-Leste [+]        NaN        NaN        NaN          NaN
# 196      Uzbekistan [+]        NaN        NaN        NaN          NaN
# 197           Yemen [+]        NaN        NaN        NaN          NaN
# 198     South Sudan [+]        NaN        NaN        NaN          NaN
#
#             1976         1980         1984         1988         1992  \
# ...

# %%
pib_totales["Countries"] = pib_totales["Countries"].str.split(" \[", n=1, expand=True)[0]

# %%
pib_totales
# Out:
#           Countries       1960       1964       1968         1972  \
# 0     United States  $542,400M  $684,500M  $940,700M  $1,279,100M
# 1         Euro zone  $244,833M  $373,024M  $518,992M    $879,867M
# 2    United Kingdom   $73,234M   $94,408M  $107,760M    $169,965M
# 3           Germany        NaN        NaN        NaN    $299,802M
# 4            France   $62,226M   $94,008M  $129,785M    $203,494M
# ..              ...        ...        ...        ...          ...
# 194      Tajikistan        NaN        NaN        NaN          NaN
# 195     Timor-Leste        NaN        NaN        NaN          NaN
# 196      Uzbekistan        NaN        NaN        NaN          NaN
# 197           Yemen        NaN        NaN        NaN          NaN
# 198     South Sudan        NaN        NaN        NaN          NaN
#
#             1976         1980         1984         1988         1992  \
# 0    $1,873,400M  $2,857,300M  $4,037,600M  $5,236,400M  $6,520,300M
# ...

# %% [markdown]
# Aquí ya tengo la tabla de Totales

# %%
pib_totales.to_csv("pib_totales.csv",index=False)

# %% [markdown]
# ---
# ---
# ---
# ---

# %%
import pandas as pd

# %%
pib_pc_1960=pd.read_csv("PIB/per_capita/1960.csv",sep=";")
pib_pc_1964=pd.read_csv("PIB/per_capita/1964.csv",sep=";")
pib_pc_1968=pd.read_csv("PIB/per_capita/1968.csv",sep=";")
pib_pc_1972=pd.read_csv("PIB/per_capita/1972.csv",sep=";")
pib_pc_1976=pd.read_csv("PIB/per_capita/1976.csv",sep=";")
pib_pc_1980=pd.read_csv("PIB/per_capita/1980.csv",sep=";")
pib_pc_1984=pd.read_csv("PIB/per_capita/1984.csv",sep=";")
pib_pc_1988=pd.read_csv("PIB/per_capita/1988.csv",sep=";")
pib_pc_1992=pd.read_csv("PIB/per_capita/1992.csv",sep=";")
pib_pc_1996=pd.read_csv("PIB/per_capita/1996.csv",sep=";")
pib_pc_2000=pd.read_csv("PIB/per_capita/2000.csv",sep=";")
pib_pc_2004=pd.read_csv("PIB/per_capita/2004.csv",sep=";")
pib_pc_2008=pd.read_csv("PIB/per_capita/2008.csv",sep=";")
pib_pc_2012=pd.read_csv("PIB/per_capita/2012.csv",sep=";")
pib_pc_2016=pd.read_csv("PIB/per_capita/2016.csv",sep=";")
pib_pc_2021=pd.read_csv("PIB/per_capita/2021.csv",sep=";")

# %%
pib_pc_2021
# Out:
#               Countries  Date GDP per capita  Unnamed: 3  \
# 0     United States [+]  2021        $69,227         NaN
# 1         Euro zone [+]  2021        $42,508         NaN
# 2    United Kingdom [+]  2021        $46,681         NaN
# 3           Germany [+]  2021        $51,238         NaN
# 4            France [+]  2021        $45,188         NaN
# ..                  ...   ...            ...         ...
# 192           Samoa [+]  2021         $3,858         NaN
# 193           Yemen [+]  2021           $639         NaN
# 194    South Africa [+]  2021         $6,965         NaN
# 195          Zambia [+]  2021         $1,094         NaN
# 196        Zimbabwe [+]  2021         $1,774         NaN
#
#     GDP P.C. Annual Growth  Unnamed: 5
# 0                     9.8%         NaN
# 1                    11.3%         NaN
# 2                    13.5%         NaN
# 3                     9.6%         NaN
# 4                    11.9%         NaN
# ..                     ...         ...
# ...

# %%
pib_pc_1960=pib_pc_1960.rename(columns={"GDP per capita":"1960"})
pib_pc_1964=pib_pc_1964.rename(columns={"GDP per capita":"1964"})
pib_pc_1968=pib_pc_1968.rename(columns={"GDP per capita":"1968"})
pib_pc_1972=pib_pc_1972.rename(columns={"GDP per capita":"1972"})
pib_pc_1976=pib_pc_1976.rename(columns={"GDP per capita":"1976"})
pib_pc_1980=pib_pc_1980.rename(columns={"GDP per capita":"1980"})
pib_pc_1984=pib_pc_1984.rename(columns={"GDP per capita":"1984"})
pib_pc_1988=pib_pc_1988.rename(columns={"GDP per capita":"1988"})
pib_pc_1992=pib_pc_1992.rename(columns={"GDP per capita":"1992"})
pib_pc_1996=pib_pc_1996.rename(columns={"GDP per capita":"1996"})
pib_pc_2000=pib_pc_2000.rename(columns={"GDP per capita":"2000"})
pib_pc_2004=pib_pc_2004.rename(columns={"GDP per capita":"2004"})
pib_pc_2008=pib_pc_2008.rename(columns={"GDP per capita":"2008"})
pib_pc_2012=pib_pc_2012.rename(columns={"GDP per capita":"2012"})
pib_pc_2016=pib_pc_2016.rename(columns={"GDP per capita":"2016"})
pib_pc_2021=pib_pc_2021.rename(columns={"GDP per capita":"2021"})

# %%
dfs_pib_pc=[pib_pc_1960,pib_pc_1964,pib_pc_1968,pib_pc_1972,pib_pc_1976,
             pib_pc_1980,pib_pc_1984,pib_pc_1988,pib_pc_1992,pib_pc_1996,
             pib_pc_2000,pib_pc_2004,pib_pc_2008,pib_pc_2012,pib_pc_2016,
             pib_pc_2021]
columnas_a_eliminar=["Unnamed: 3","Date","GDP P.C. Annual Growth","Unnamed: 5"]
for i in dfs_pib_pc:
    i.drop(columns=columnas_a_eliminar,axis=1,inplace=True)

# %%
pib_percapita=pib_pc_1960

# %%
for i in dfs_pib_pc[1:]:
    pib_percapita=pd.merge(pib_percapita,i,on="Countries",how="outer")

# %%
pib_percapita["Countries"] = pib_percapita["Countries"].str.split(" \[", n=1, expand=True)[0]

# %%
pib_percapita
# Out:
#           Countries    1960    1964    1968    1972    1976     1980     1984  \
# 0     United States  $3,014  $3,582  $4,720  $6,112  $8,611  $12,553  $17,086
# 1         Euro zone    $923  $1,380  $1,828  $3,025  $5,399  $10,025   $7,830
# 2    United Kingdom  $1,392  $1,742  $1,947  $3,026  $4,139  $10,715   $8,939
# 3           Germany     NaN     NaN     NaN  $4,850  $8,459  $11,110   $8,538
# 4            France  $1,335  $1,910  $2,536  $3,855  $6,867  $13,070   $9,697
# ..              ...     ...     ...     ...     ...     ...      ...      ...
# 192      Tajikistan     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 193     Timor-Leste     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 194      Uzbekistan     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 195           Yemen     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 196     South Sudan     NaN     NaN     NaN     NaN     NaN      NaN      NaN
#
# ...

# %%
pib_percapita.to_csv("pib_percapita.csv",index=False)

# %% [markdown]
# Listo!
#
# ----
# ---
# ---

# %% [markdown]
# Resumen Número de Atletas y Sedes

# %%
num_atletas_y_paises=pd.read_csv("data/Resumen num atletas y paises_.csv",sep=";")

# %%
num_atletas_y_paises
# Out:
#    Olympiad         Host city  Nations  Athletes
# 0      XXXV     Brisbane 2032      NaN       NaN
# 1     XXXIV  Los Angeles 2028      NaN       NaN
# 2    XXXIII        Paris 2024      NaN       NaN
# 3     XXXII        Tokyo 2020    206.0   11315.0
# 4      XXXI          Rio 2016    207.0   11238.0
# 5       XXX       London 2012    205.0   10500.0
# 6      XXIX      Beijing 2008    204.0   10942.0
# 7    XXVIII       Athens 2004    201.0   10625.0
# 8     XXVII       Sydney 2000    199.0   10651.0
# 9      XXVI      Atlanta 1996    197.0   10318.0
# 10      XXV    Barcelona 1992    169.0    9356.0
# 11     XXIV        Seoul 1988    159.0    8391.0
# 12    XXIII  Los Angeles 1984    140.0    6829.0
# 13     XXII       Moscow 1980     80.0    5179.0
# 14      XXI     Montreal 1976     92.0    6084.0
# 15       XX       Munich 1972    121.0    7134.0
# 16      XIX  Mexico City 1968    112.0    5516.0
# 17    XVIII        Tokyo 1964     93.0    5151.0
# ...

# %%
num_atletas_y_paises.to_csv("num_atletas_y_paises.csv",index=False)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# Voy a intentar subir los df de 2020

# %% [markdown]
# primero el listado individual de atletas de 2020 para sacar estadísticas de:
# *numero de atletas
# *edad
# *genero
# *país
# *...
# MEDALLAS NO

# %%
import pandas as pd

# %%
atletas_completo_2021=pd.read_csv("data/Atletas_indiv_2020.csv",sep=";")

# %%
atletas_completo_2021.drop(["short_name","birth_place","birth_country","residence_place","residence_country","url","Columna1"],axis=1,inplace=True)

# %%
atletas_completo_2021
# Out:
#                         name  gender  birth_date  country country_code  \
# 0            AALERUD Katrine  Female  04/12/1994   Norway          NOR
# 1                ABAD Nestor    Male  29/03/1993    Spain          ESP
# 2          ABAGNALE Giovanni    Male  11/01/1995    Italy          ITA
# 3             ABALDE Alberto    Male  15/12/1995    Spain          ESP
# 4              ABALDE Tamara  Female  06/02/1989    Spain          ESP
# ...                      ...     ...         ...      ...          ...
# 11640  ZWICKER Martin Detlef    Male  27/02/1987  Germany          GER
# 11641      ZWOLINSKA Klaudia  Female  18/12/1998   Poland          POL
# 11642           ZYKOVA Yulia  Female  25/11/1995      ROC          ROC
# 11643      ZYUZINA Ekaterina  Female  08/12/1996      ROC          ROC
# 11644        ZYZANSKA Sylwia  Female  27/07/1997   Poland          POL
#
#                 discipline discipline_code height_m/ft
# 0             Cycling Road             CRD         NaN
# ...

# %%
atletas_completo_2021["height_m/ft"]=atletas_completo_2021["height_m/ft"].str.split("/",n=1,expand=True)[0]

# %%
atletas_completo_2021["height_m/ft"]
# Out:
# 0         NaN
# 1        1.65
# 2        1.98
# 3        2.00
# 4        1.92
#          ...
# 11640    1.76
# 11641     NaN
# 11642     NaN
# 11643     NaN
# 11644     NaN
# Name: height_m/ft, Length: 11645, dtype: object

# %%
atletas_completo_2021["height_m/ft"].fillna(0,inplace=True)

# %%
atletas_completo_2021["height_m/ft"]=atletas_completo_2021["height_m/ft"].astype(float)

# %%
atletas_completo_2021["height_m/ft"]=atletas_completo_2021["height_m/ft"]*100

# %%
atletas_completo_2021
# Out:
#                         name  gender  birth_date  country country_code  \
# 0            AALERUD Katrine  Female  04/12/1994   Norway          NOR
# 1                ABAD Nestor    Male  29/03/1993    Spain          ESP
# 2          ABAGNALE Giovanni    Male  11/01/1995    Italy          ITA
# 3             ABALDE Alberto    Male  15/12/1995    Spain          ESP
# 4              ABALDE Tamara  Female  06/02/1989    Spain          ESP
# ...                      ...     ...         ...      ...          ...
# 11640  ZWICKER Martin Detlef    Male  27/02/1987  Germany          GER
# 11641      ZWOLINSKA Klaudia  Female  18/12/1998   Poland          POL
# 11642           ZYKOVA Yulia  Female  25/11/1995      ROC          ROC
# 11643      ZYUZINA Ekaterina  Female  08/12/1996      ROC          ROC
# 11644        ZYZANSKA Sylwia  Female  27/07/1997   Poland          POL
#
#                 discipline discipline_code  height_m/ft
# 0             Cycling Road             CRD          0.0
# ...

# %%
atletas_completo_2021
# Out:
#                         name  gender  birth_date  country country_code  \
# 0            AALERUD Katrine  Female  04/12/1994   Norway          NOR
# 1                ABAD Nestor    Male  29/03/1993    Spain          ESP
# 2          ABAGNALE Giovanni    Male  11/01/1995    Italy          ITA
# 3             ABALDE Alberto    Male  15/12/1995    Spain          ESP
# 4              ABALDE Tamara  Female  06/02/1989    Spain          ESP
# ...                      ...     ...         ...      ...          ...
# 11640  ZWICKER Martin Detlef    Male  27/02/1987  Germany          GER
# 11641      ZWOLINSKA Klaudia  Female  18/12/1998   Poland          POL
# 11642           ZYKOVA Yulia  Female  25/11/1995      ROC          ROC
# 11643      ZYUZINA Ekaterina  Female  08/12/1996      ROC          ROC
# 11644        ZYZANSKA Sylwia  Female  27/07/1997   Poland          POL
#
#                 discipline discipline_code  height_m/ft
# 0             Cycling Road             CRD          0.0
# ...

# %%
import datetime
atletas_completo_2021["birth_date"]=pd.to_datetime(atletas_completo_2021["birth_date"])

# %%
atletas_completo_2021["birth_year"]=atletas_completo_2021["birth_date"].dt.year

# %%
atletas_completo_2021["Age"]=2021-atletas_completo_2021["birth_year"]

# %%
atletas_completo_2021 #Unir esto con lo último
# Out:
#                         name  gender birth_date  country country_code  \
# 0            AALERUD Katrine  Female 1994-04-12   Norway          NOR
# 1                ABAD Nestor    Male 1993-03-29    Spain          ESP
# 2          ABAGNALE Giovanni    Male 1995-11-01    Italy          ITA
# 3             ABALDE Alberto    Male 1995-12-15    Spain          ESP
# 4              ABALDE Tamara  Female 1989-06-02    Spain          ESP
# ...                      ...     ...        ...      ...          ...
# 11640  ZWICKER Martin Detlef    Male 1987-02-27  Germany          GER
# 11641      ZWOLINSKA Klaudia  Female 1998-12-18   Poland          POL
# 11642           ZYKOVA Yulia  Female 1995-11-25      ROC          ROC
# 11643      ZYUZINA Ekaterina  Female 1996-08-12      ROC          ROC
# 11644        ZYZANSKA Sylwia  Female 1997-07-27   Poland          POL
#
#                 discipline discipline_code  height_m/ft  birth_year   Age
# ...

# %% [markdown]
# Ahora voy a sacar el listado todos de medallistas de 2020

# %%
medallistas_2021=pd.read_csv("data/Medallistas_2020.csv",sep=";")

# %%
medallistas_2021.drop(["medal_code","medal_date","athlete_short_name","athlete_link","athlete_name.1","medal_type.1","athlete_sex.1","country_code.1","discipline_code.1","event.1"],axis=1,inplace=True)

# %%
medallistas_2021["athlete_name"].value_counts() #Aquí vemos quienes ganaron más medallas
# Out:
# McKEON Emma            7
# DRESSEL Caeleb         5
# ZHANG Yufei            4
# McKEOWN Kaylee         4
# SCOTT Duncan           4
#                       ..
# CIOFANI Anne-Cecile    1
# BERTRAND Coralie       1
# BRAZIER Kelly          1
# HIRINI Sarah           1
# ZALANKI Gergo          1
# Name: athlete_name, Length: 2174, dtype: int64

# %% [markdown]
# Ahora voy a subir el documento de todos los atletas y medallistas juntos. Es decir, el que ganó 2 medallas, aparece 2 veces y el que no ganó nada, o ganó 1 medalla, aparece 1 vez

# %%
repetidos_medallistas_2021=pd.read_csv("data/Atletas_completo_medallistas_repetidos_2020.csv",sep=";")

# %%
repetidos_medallistas_2021["event"]
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#                     ...
# 11868                            NaN
# 11869                            NaN
# 11870    50m Rifle 3 Positions Women
# 11871                            NaN
# 11872                            NaN
# Name: event, Length: 11873, dtype: object

# %%
repetidos_medallistas_2021.drop(["medal_code","medal_date","athlete_short_name","athlete_link","Unnamed: 12","Unnamed: 13","Unnamed: 14","Unnamed: 15","Unnamed: 16","Unnamed: 17"],axis=1,inplace=True)

# %%
repetidos_medallistas_2021
# Out:
#          medal_type           athlete_name athlete_sex country_code  \
# 0               NaN        AALERUD Katrine      Female          NOR
# 1               NaN            ABAD Nestor        Male          ESP
# 2               NaN      ABAGNALE Giovanni        Male          ITA
# 3               NaN         ABALDE Alberto        Male          ESP
# 4               NaN          ABALDE Tamara      Female          ESP
# ...             ...                    ...         ...          ...
# 11868           NaN  ZWICKER Martin Detlef        Male          GER
# 11869           NaN      ZWOLINSKA Klaudia      Female          POL
# 11870  Silver Medal           ZYKOVA Yulia           W          ROC
# 11871           NaN      ZYUZINA Ekaterina      Female          ROC
# 11872           NaN        ZYZANSKA Sylwia      Female          POL
#
#       discipline_code                        event  country  \
# 0                 CRD                          NaN   Norway
# ...

# %%
mask1=repetidos_medallistas_2021["athlete_sex"]=="Female"
repetidos_medallistas_2021.loc[mask1,"athlete_sex"]="W"

# %%
mask1=repetidos_medallistas_2021["athlete_sex"]=="Male"
repetidos_medallistas_2021.loc[mask1,"athlete_sex"]="M"

# %%
repetidos_medallistas_2021["athlete_sex"].unique()
# Out:
# array(['W', 'M', 'X', 'O'], dtype=object)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# Vamos con df de Atletismo en Olimpiadas (Booleano)

# %%
atletismo_olimpiadas=pd.read_csv("data/Atletismo en olimpiadas(True,False).csv",sep=";")

# %%
atletismo_olimpiadas=atletismo_olimpiadas.rename(columns={"Unnamed: 0":"Year"})

# %%
atletismo_olimpiadas.set_index("Year",inplace=True)

# %%
atletismo_olimpiadas
# Out:
#       100m M  100 W  200m M  200m W  400m M  400m W  800m M  800m W  1500m M  \
# Year
# 1896    True  False   False   False    True   False    True   False     True
# 1900    True  False    True   False    True   False    True   False     True
# 1904    True  False    True   False    True   False    True   False     True
# 1908    True  False    True   False    True   False    True   False     True
# 1912    True  False    True   False    True   False    True   False     True
# 1916   False  False   False   False   False   False   False   False    False
# 1920    True  False    True   False    True   False    True   False     True
# 1924    True  False    True   False    True   False    True   False     True
# 1928    True   True    True   False    True   False    True    True     True
# 1932    True   True    True   False    True   False    True   False     True
# 1936    True   True   False   False    True   False   False   False     True
# ...

# %%
#atletismo_olimpiadas.to_csv("atletismo_olimpiadas.csv",index=False)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# Ahora vamos a hacer lo mismo con las database de 1896-2016

# %%
repetidos_medallistas_1896_2016=pd.read_csv("data/athlete_events.csv",sep=",")

# %%
repetidos_medallistas_1896_2016
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
repetidos_medallistas_1896_2016=repetidos_medallistas_1896_2016[repetidos_medallistas_1896_2016["Season"]=="Summer"]

# %%
len(repetidos_medallistas_1896_2016.index)
# Out:
# 222552

# %%
repetidos_medallistas_1896_2016.groupby("Year").mean()
# Out:
#                 ID        Age      Height     Weight
# Year
# 1896  71099.757895  23.580645  172.739130  71.387755
# 1900  63681.200930  29.034031  176.637931  74.556962
# 1904  70258.328978  26.698150  175.788732  72.197279
# 1906  70696.454703  27.125253  178.206226  75.917073
# 1908  66412.000967  26.970228  177.543158  75.386128
# 1912  67462.126733  27.538620  177.447989  73.117450
# 1920  66991.033085  29.290978  175.752282  73.106157
# 1924  67403.290273  28.449373  175.239548  71.812018
# 1928  69287.245593  29.414907  175.331770  70.941791
# 1932  65783.303469  33.451540  174.371681  70.897980
# 1936  68822.910083  27.878331  176.112689  71.630363
# 1948  66957.768618  29.304796  176.600190  71.942308
# 1952  68706.643773  26.258851  174.183023  70.096173
# 1956  69529.477082  26.033673  174.116567  70.364200
# 1960  66691.701564  25.298760  173.310287  69.393811
# 1964  68016.418982  25.065283  173.690848  69.686692
# 1968  66975.890661  24.255154  174.087484  69.454786
# ...

# %%
repetidos_medallistas_1896_2016["Age"][repetidos_medallistas_1896_2016["Year"]==1932].sum()
# Out:
# 89048.0

# %%
len(repetidos_medallistas_1896_2016["Age"][repetidos_medallistas_1896_2016["Year"]==1932])
# Out:
# 2969

# %%
#Aparentemente las alturas, pesos y edades no han variado a lo largo del tiempo. Comprobar cuántos datos tengo (totales y relativos) de cada edición

# %%
repetidos_medallistas_1896_2016.groupby("Year")["Name"]
#Lo que quiero es sacar los deportistas no-repetidos de cada año

# %%
amigos=pd.DataFrame({"Year":[2000,2001,2004,2005,2008,2000,2001,2000,2000],"amigos":["Pedro","Ana","Maria","Pedro","Juan","Miriam","Ana","Pedro","Javi"]})

# %%
amigos.groupby("Year")["amigos"].count()
# Out:
# Year
# 2000    4
# 2001    2
# 2004    1
# 2005    1
# 2008    1
# Name: amigos, dtype: int64

# %%
amigos.groupby("Year")["amigos"].agg(list)
# Out:
# Year
# 2000    [Pedro, Miriam, Pedro, Javi]
# 2001                      [Ana, Ana]
# 2004                         [Maria]
# 2005                         [Pedro]
# 2008                          [Juan]
# Name: amigos, dtype: object

# %%
amigos.groupby("Year")["amigos"].agg(set)
# Out:
# Year
# 2000    {Pedro, Javi, Miriam}
# 2001                    {Ana}
# 2004                  {Maria}
# 2005                  {Pedro}
# 2008                   {Juan}
# Name: amigos, dtype: object

# %%
amigos.groupby("Year")["amigos"].agg(set).apply(len)
# Out:
# Year
# 2000    3
# 2001    1
# 2004    1
# 2005    1
# 2008    1
# Name: amigos, dtype: int64

# %%
#Unir repetidos_medallistas_1896_2016 y repetidos_medallistas_2021

# %%
#1896_2016=Name, Sex, Age, Height, Weight, Team, NOC, Year, City, Sport, Medal.
#2021= athlete_name, athlete_sex, country_code, country, discipline, medal_type

#Unificar las columnas
#Name            Sex             Age     Height  Weight              Team        NOC             Year    City        Sport       Medal
#athlete_name    athlete_sex     ??      ??      (no tengo nada)     country     country_code    "2021"  "Tokyo"     discipline  medal_type

# %%
repetidos_medallistas_1896_2016[["Name","Sex","Age","Height","Weight","Team","NOC","Year","City","Sport","Medal"]]
# Out:
#                                       Name Sex   Age  Height  Weight  \
# 0                                A Dijiang   M  24.0   180.0    80.0
# 1                                 A Lamusi   M  23.0   170.0    60.0
# 2                      Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3                     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26      Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...                                    ...  ..   ...     ...     ...
# 271106            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC  Year            City       Sport Medal
# 0                China  CHN  1992       Barcelona  Basketball   NaN
# ...

# %%
repetidos_medallistas_1896_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222552 entries, 0 to 271110
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      222552 non-null  int64
#  1   Name    222552 non-null  object
#  2   Sex     222552 non-null  object
#  3   Age     213363 non-null  float64
#  4   Height  170695 non-null  float64
#  5   Weight  168698 non-null  float64
#  6   Team    222552 non-null  object
#  7   NOC     222552 non-null  object
#  8   Games   222552 non-null  object
#  9   Year    222552 non-null  int64
#  10  Season  222552 non-null  object
#  11  City    222552 non-null  object
#  12  Sport   222552 non-null  object
#  13  Event   222552 non-null  object
#  14  Medal   34088 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 35.2+ MB

# %%
edades_2021=atletas_completo_2021[["name","Age"]]
edades_2021.rename(columns={"name":"athlete_name"},inplace=True)
repetidos_medallistas_2021=pd.merge(repetidos_medallistas_2021,edades_2021,on="athlete_name",how="inner")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
atletas_completo_2021=atletas_completo_2021.rename(columns={"height_m/ft":"Height"})
alturas_2021=atletas_completo_2021[["name","Height"]]
alturas_2021.rename(columns={"name":"athlete_name"},inplace=True)
repetidos_medallistas_2021=pd.merge(repetidos_medallistas_2021,alturas_2021,on="athlete_name",how="inner")

# %%
import numpy as np

repetidos_medallistas_2021["Weight"]=np.nan
repetidos_medallistas_2021["Year"]=2021
repetidos_medallistas_2021["City"]="Tokyo"

# %%
repetidos_medallistas_2021
# Out:
#          medal_type           athlete_name athlete_sex country_code  \
# 0               NaN        AALERUD Katrine           W          NOR
# 1               NaN            ABAD Nestor           M          ESP
# 2               NaN      ABAGNALE Giovanni           M          ITA
# 3               NaN         ABALDE Alberto           M          ESP
# 4               NaN          ABALDE Tamara           W          ESP
# ...             ...                    ...         ...          ...
# 11955           NaN  ZWICKER Martin Detlef           M          GER
# 11956           NaN      ZWOLINSKA Klaudia           W          POL
# 11957  Silver Medal           ZYKOVA Yulia           W          ROC
# 11958           NaN      ZYUZINA Ekaterina           W          ROC
# 11959           NaN        ZYZANSKA Sylwia           W          POL
#
#       discipline_code                        event  country  \
# 0                 CRD                          NaN   Norway
# ...

# %%
repetidos_medallistas_2021.rename(columns={"athlete_name":"Name","athlete_sex":"Sex","country":"Team","country_code":"NOC","discipline":"Sport","medal_type":"Medal","event":"Event"},inplace=True)

# %%
repetidos_medallistas_2021=repetidos_medallistas_2021[["Name","Sex","Age","Height","Weight","Team","NOC","Year","City","Sport","Event","Medal"]]

# %%
repetidos_medallistas_1896_2016.drop(["ID","Games","Season"],axis=1,inplace=True)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
repetidos_medallistas_1896_2016.head(2)
# Out:
#         Name Sex   Age  Height  Weight   Team  NOC  Year       City  \
# 0  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992  Barcelona
# 1   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012     London
#
#         Sport                         Event Medal
# 0  Basketball   Basketball Men's Basketball   NaN
# 1        Judo  Judo Men's Extra-Lightweight   NaN

# %%
repetidos_medallistas_2021.head()
# Out:
#                 Name Sex   Age  Height  Weight    Team  NOC  Year   City  \
# 0    AALERUD Katrine   W  27.0     0.0     NaN  Norway  NOR  2021  Tokyo
# 1        ABAD Nestor   M  28.0   165.0     NaN   Spain  ESP  2021  Tokyo
# 2  ABAGNALE Giovanni   M  26.0   198.0     NaN   Italy  ITA  2021  Tokyo
# 3     ABALDE Alberto   M  26.0   200.0     NaN   Spain  ESP  2021  Tokyo
# 4      ABALDE Tamara   W  32.0   192.0     NaN   Spain  ESP  2021  Tokyo
#
#                  Sport Event Medal
# 0         Cycling Road   NaN   NaN
# 1  Artistic Gymnastics   NaN   NaN
# 2               Rowing   NaN   NaN
# 3           Basketball   NaN   NaN
# 4           Basketball   NaN   NaN

# %%
repetidos_medallistas_1896_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222552 entries, 0 to 271110
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    222552 non-null  object
#  1   Sex     222552 non-null  object
#  2   Age     213363 non-null  float64
#  3   Height  170695 non-null  float64
#  4   Weight  168698 non-null  float64
#  5   Team    222552 non-null  object
#  6   NOC     222552 non-null  object
#  7   Year    222552 non-null  int64
#  8   City    222552 non-null  object
#  9   Sport   222552 non-null  object
#  10  Event   222552 non-null  object
#  11  Medal   34088 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 30.1+ MB

# %%
repetidos_medallistas_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11960 entries, 0 to 11959
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    11960 non-null  object
#  1   Sex     11960 non-null  object
#  2   Age     11801 non-null  float64
#  3   Height  11960 non-null  float64
#  4   Weight  0 non-null      float64
#  5   Team    11960 non-null  object
#  6   NOC     11960 non-null  object
#  7   Year    11960 non-null  int64
#  8   City    11960 non-null  object
#  9   Sport   11821 non-null  object
#  10  Event   2410 non-null   object
#  11  Medal   2410 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
repetidos_total=pd.concat([repetidos_medallistas_1896_2016,repetidos_medallistas_2021])

# %%
repetidos_total.reset_index(inplace=True)
repetidos_total.drop(["index"],axis=1,inplace=True)

# %%
repetidos_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234512 entries, 0 to 234511
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    234512 non-null  object
#  1   Sex     234512 non-null  object
#  2   Age     225164 non-null  float64
#  3   Height  182655 non-null  float64
#  4   Weight  168698 non-null  float64
#  5   Team    234512 non-null  object
#  6   NOC     234512 non-null  object
#  7   Year    234512 non-null  int64
#  8   City    234512 non-null  object
#  9   Sport   234373 non-null  object
#  10  Event   224962 non-null  object
#  11  Medal   36498 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 21.5+ MB

# %%
len(repetidos_total.index)
# Out:
# 234512

# %%
repetidos_total.to_csv("repetidos_total.csv",index=False)

# %% [markdown]
# ---
# ---
# ---
# Aquí empiezo a "limpiar" a ojo la tabla mirando valores extraños

# %% [markdown]
# ---
# Height

# %%
repetidos_total["Height"].sort_values(ascending=False)
# Out:
# 230081    14133.0
# 217741      226.0
# 217742      226.0
# 217743      226.0
# 170575      223.0
#            ...
# 222507        NaN
# 222510        NaN
# 222512        NaN
# 222525        NaN
# 222542        NaN
# Name: Height, Length: 234512, dtype: float64

# %%
repetidos_total["Height"].mean()
# Out:
# 168.70138238756124

# %%
repetidos_total["Height"].sort_values(ascending=False)
# Out:
# 230081    14133.0
# 217741      226.0
# 217742      226.0
# 217743      226.0
# 170575      223.0
#            ...
# 222507        NaN
# 222510        NaN
# 222512        NaN
# 222525        NaN
# 222542        NaN
# Name: Height, Length: 234512, dtype: float64

# %%
repetidos_total.loc[230081,"Height"]=np.nan
repetidos_total.loc[233442,"Height"]=np.nan

# %%
repetidos_total["Height"].replace(0, np.nan, inplace=True)

# %%
repetidos_total["Height"].mean(skipna=True)
# Out:
# 175.58671584612227

# %%
repetidos_total["Height"].nsmallest(20)
# Out:
# 24419     127.0
# 24420     127.0
# 24421     127.0
# 24422     127.0
# 24423     127.0
# 24424     127.0
# 135733    127.0
# 228825    127.0
# 148705    128.0
# 131567    130.0
# 180943    130.0
# 57606     131.0
# 57607     131.0
# 3106      132.0
# 3374      132.0
# 37049     132.0
# 122014    132.0
# 122015    132.0
# 122016    132.0
# 122017    132.0
# Name: Height, dtype: float64

# %% [markdown]
# ---
# Weight

# %%
repetidos_total["Weight"].nlargest(10)
# Out:
# 19294     214.0
# 19295     214.0
# 169114    198.0
# 62602     190.0
# 194467    182.0
# 194468    182.0
# 169782    180.0
# 169527    178.0
# 78229     176.5
# 78230     176.5
# Name: Weight, dtype: float64

# %%
repetidos_total["Weight"].nsmallest(10)
# Out:
# 34215    25.0
# 34216    25.0
# 34217    25.0
# 34218    25.0
# 34219    25.0
# 34220    25.0
# 90676    28.0
# 90677    28.0
# 90678    28.0
# 90679    28.0
# Name: Weight, dtype: float64

# %%
repetidos_total["Weight"].mean(skipna=True)
# Out:
# 70.68905973989021

# %% [markdown]
# ---
# Edad

# %%
repetidos_total["Age"].nlargest(20)
# Out:
# 211066    97.0
# 81200     96.0
# 51105     88.0
# 51106     88.0
# 51107     88.0
# 8017      84.0
# 127244    81.0
# 194356    81.0
# 113846    80.0
# 113847    80.0
# 113848    80.0
# 140912    77.0
# 140913    77.0
# 47591     76.0
# 47592     76.0
# 47593     76.0
# 52727     76.0
# 109456    76.0
# 109457    76.0
# 140761    76.0
# Name: Age, dtype: float64

# %%
repetidos_total["Sport"][repetidos_total["Age"]>70].unique()
# Out:
# array(['Art Competitions', 'Equestrianism', 'Sailing', 'Archery',
#        'Shooting'], dtype=object)

# %%
repetidos_total["Age"].mean(skipna=True)
# Out:
# 25.76188467072889

# %%
mask2=repetidos_total["Sport"]!="Art Competitions"

# %%
repetidos_total[mask2]["Age"].mean() #Vemos que quitando a los deportistas de Arte, la media de edad baja
# Out:
# 25.48341010297488

# %% [markdown]
# ---
# más participaciones

# %%
repetidos_total["Name"].value_counts()
# Out:
# Robert Tait McKenzie        58
# Heikki Ilmari Savolainen    39
# Joseph "Josy" Stoffel       38
# Ioannis Theofilakis         36
# Takashi Ono                 33
#                             ..
# Anita Kobu (Nner-)           1
# Agnieszka Kobus              1
# Elias Kobti                  1
# Mary Elizabeth Koboldt       1
# ZYZANSKA Sylwia              1
# Name: Name, Length: 127751, dtype: int64

# %%
repetidos_total.groupby(["Year"])["Name"].agg(set).apply(len) #El total de participantes únicos en cada edición
# Out:
# Year
# 1896      176
# 1900     1220
# 1904      650
# 1906      841
# 1908     2024
# 1912     2409
# 1920     2675
# 1924     3256
# 1928     3246
# 1932     1922
# 1936     4482
# 1948     4402
# 1952     4931
# 1956     3346
# 1960     5348
# 1964     5134
# 1968     5552
# 1972     7105
# 1976     6070
# 1980     5252
# 1984     6791
# 1988     8443
# 1992     9380
# 1996    10324
# 2000    10639
# 2004    10537
# 2008    10880
# 2012    10502
# 2016    11174
# 2021    11629
# Name: Name, dtype: int64

# %%
num_atletas_y_paises
# Out:
#    Olympiad         Host city  Nations  Athletes
# 0      XXXV     Brisbane 2032      NaN       NaN
# 1     XXXIV  Los Angeles 2028      NaN       NaN
# 2    XXXIII        Paris 2024      NaN       NaN
# 3     XXXII        Tokyo 2020    206.0   11315.0
# 4      XXXI          Rio 2016    207.0   11238.0
# 5       XXX       London 2012    205.0   10500.0
# 6      XXIX      Beijing 2008    204.0   10942.0
# 7    XXVIII       Athens 2004    201.0   10625.0
# 8     XXVII       Sydney 2000    199.0   10651.0
# 9      XXVI      Atlanta 1996    197.0   10318.0
# 10      XXV    Barcelona 1992    169.0    9356.0
# 11     XXIV        Seoul 1988    159.0    8391.0
# 12    XXIII  Los Angeles 1984    140.0    6829.0
# 13     XXII       Moscow 1980     80.0    5179.0
# 14      XXI     Montreal 1976     92.0    6084.0
# 15       XX       Munich 1972    121.0    7134.0
# 16      XIX  Mexico City 1968    112.0    5516.0
# 17    XVIII        Tokyo 1964     93.0    5151.0
# ...

# %%
repetidos_total.groupby("Name")["Year"].nunique().sort_values(ascending=False) #Más  participaciones en juegos olímpicos diferentes
# Out:
# Name
# Ian Millar                    10
# Afanasijs Kuzmins              9
# Hubert Raudaschl               9
# Rajmond Debevec                8
# Piero D'Inzeo                  8
#                               ..
# Hugues Fabrice Zango           1
# Hugues De Roussan              1
# Hugues Broussard               1
# Hugo scar Prono Pellegrini     1
# Karl Magnus Augustson          1
# Name: Year, Length: 127751, dtype: int64

# %%
repetidos_total[repetidos_total["NOC"] == "USA"].groupby("Year")["Medal"].count() #Medallas de USA en cada edición
# Out:
# Year
# 1896     20
# 1900     63
# 1904    394
# 1906     24
# 1908     65
# 1912    107
# 1920    194
# 1924    182
# 1928     88
# 1932    189
# 1936     96
# 1948    152
# 1952    134
# 1956    123
# 1960    125
# 1964    169
# 1968    166
# 1972    171
# 1976    164
# 1984    352
# 1988    207
# 1992    224
# 1996    259
# 2000    242
# 2004    263
# 2008    317
# 2012    248
# 2016    264
# 2021    295
# Name: Medal, dtype: int64

# %%
repetidos_total.groupby("Year")["Medal"].count()
# Out:
# Year
# 1896     143
# 1900     604
# 1904     486
# 1906     458
# 1908     831
# 1912     941
# 1920    1308
# 1924     832
# 1928     734
# 1932     647
# 1936     917
# 1948     852
# 1952     897
# 1956     893
# 1960     911
# 1964    1029
# 1968    1057
# 1972    1215
# 1976    1320
# 1980    1384
# 1984    1476
# 1988    1582
# 1992    1712
# 1996    1842
# 2000    2004
# 2004    2001
# 2008    2048
# 2012    1941
# 2016    2023
# 2021    2410
# Name: Medal, dtype: int64

# %%
# Unir los DataFrames por año
merged = repetidos_total.groupby("Year")["Medal"].count().reset_index().merge(
    repetidos_total[repetidos_total["NOC"] == "USA"].groupby("Year")["Medal"].count().reset_index(),
    on="Year",
    suffixes=("_total", "_usa")
)

# Calcular el porcentaje de medallas ganadas por Estados Unidos en cada edición
merged["Porcentaje"] = merged["Medal_usa"] / merged["Medal_total"] * 100

# %%
merged
# Out:
#     Year  Medal_total  Medal_usa  Porcentaje
# 0   1896          143         20   13.986014
# 1   1900          604         63   10.430464
# 2   1904          486        394   81.069959
# 3   1906          458         24    5.240175
# 4   1908          831         65    7.821901
# 5   1912          941        107   11.370882
# 6   1920         1308        194   14.831804
# 7   1924          832        182   21.875000
# 8   1928          734         88   11.989101
# 9   1932          647        189   29.211747
# 10  1936          917         96   10.468920
# 11  1948          852        152   17.840376
# 12  1952          897        134   14.938685
# 13  1956          893        123   13.773796
# 14  1960          911        125   13.721186
# 15  1964         1029        169   16.423712
# 16  1968         1057        166   15.704825
# 17  1972         1215        171   14.074074
# 18  1976         1320        164   12.424242
# 19  1984         1476        352   23.848238
# ...

# %%
merged.to_csv("porcentaje_medallas_eeuu.csv")

# %% [markdown]
# ---
# ---
# ---

# %%
#Tengo que cambiar las columnas de "Sport" y "Event" de 2021 para que queden como en la otra tabla

# %%
repetidos_total_2=repetidos_total #Por si la lío...

# %%
repetidos_total_2[(repetidos_total_2["Year"]==2016)&(repetidos_total_2["Sport"]=="Gymnastics")]
# Out:
#                        Name Sex   Age  Height  Weight         Team  NOC  Year  \
# 77        Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  ESP  2016
# 78        Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  ESP  2016
# 79        Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  ESP  2016
# 80        Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  ESP  2016
# 81        Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  ESP  2016
# ...                     ...  ..   ...     ...     ...          ...  ...   ...
# 220744      Zhang Chenglong   M  27.0   173.0    65.0        China  CHN  2016
# 220745      Zhang Chenglong   M  27.0   173.0    65.0        China  CHN  2016
# 220746      Zhang Chenglong   M  27.0   173.0    65.0        China  CHN  2016
# 221970  Epke Jan Zonderland   M  30.0   173.0    69.0  Netherlands  NED  2016
# 221971  Epke Jan Zonderland   M  30.0   173.0    69.0  Netherlands  NED  2016
#
# ...

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Cycling Road')
repetidos_total_2.loc[filt, "Sport"] = "Cycling"
repetidos_total_2.loc[filt, "Event"] = "Cycling Road"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Cycling BMX Racing')
repetidos_total_2.loc[filt, "Sport"] = "Cycling"
repetidos_total_2.loc[filt, "Event"] = "Cycling BMX Racing"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Cycling Track')
repetidos_total_2.loc[filt, "Sport"] = "Cycling"
repetidos_total_2.loc[filt, "Event"] = "Cycling Track"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Cycling Mountain Bike')
repetidos_total_2.loc[filt, "Sport"] = "Cycling"
repetidos_total_2.loc[filt, "Event"] = "Cycling Mountain Bike"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Cycling BMX Freestyle')
repetidos_total_2.loc[filt, "Sport"] = "Cycling"
repetidos_total_2.loc[filt, "Event"] = "Cycling BMX Freestyle"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Artistic Gymnastics')
repetidos_total_2.loc[filt, "Sport"] = "Gymnastics"
repetidos_total_2.loc[filt, "Event"] = "Artistic Gymnastics"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Trampoline Gymnastics')
repetidos_total_2.loc[filt, "Sport"] = "Gymnastics"
repetidos_total_2.loc[filt, "Event"] = "Trampoline Gymnastics"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Marathon Swimming')
repetidos_total_2.loc[filt, "Sport"] = "Swimming"
repetidos_total_2.loc[filt, "Event"] = "Marathon Swimming"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Artistic Swimming')
repetidos_total_2.loc[filt, "Sport"] = "Swimming"
repetidos_total_2.loc[filt, "Event"] = "Artistic Swimming"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Canoe Slalom')
repetidos_total_2.loc[filt, "Sport"] = "Canoeing"
repetidos_total_2.loc[filt, "Event"] = "Canoe Slalom"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Canoe Sprint')
repetidos_total_2.loc[filt, "Sport"] = "Canoeing"
repetidos_total_2.loc[filt, "Event"] = "Canoe Sprint"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Equestrian')
repetidos_total_2.loc[filt, "Sport"] = "Equestrianism"

# %%
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Baseball/Softball') & (repetidos_total_2["Sex"] == 'M')
repetidos_total_2.loc[filt, "Sport"] = "Baseball"
filt = (repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Baseball/Softball') & (repetidos_total_2["Sex"] == 'W')
repetidos_total_2.loc[filt, "Sport"] = "Softball"

# %%
repetidos_total_2[(repetidos_total_2['Year'] == 2021) & (repetidos_total_2['Sport'] == 'Cycling')]
# Out:
#                         Name Sex   Age  Height  Weight  \
# 222552       AALERUD Katrine   W  27.0     NaN     NaN
# 222676      AFREMOVA Natalia   W  23.0   164.0     NaN
# 222828      ALI ZADA Masomah   W  25.0     NaN     NaN
# 222860          ALMEIDA Joao   M  23.0   178.0     NaN
# 222918        ALZINI Martina   W  24.0     NaN     NaN
# ...                      ...  ..   ...     ...     ...
# 234338          ZAKELJ Tanja   W  33.0   159.0     NaN
# 234339       ZAKHAROV Artyom   M  30.0     NaN     NaN
# 234366  ZAYED AHMED Ebtissam   W  25.0     NaN     NaN
# 234424            ZHANG Peng   M  25.0     NaN     NaN
# 234460         ZHONG Tianshi   W  30.0     NaN     NaN
#
#                               Team  NOC  Year   City    Sport  \
# 222552                      Norway  NOR  2021  Tokyo  Cycling
# 222676                         ROC  ROC  2021  Tokyo  Cycling
# 222828                         EOR  EOR  2021  Tokyo  Cycling
# ...

# %%
repetidos_total_2['Sex'] = repetidos_total_2['Sex'].replace('W', 'F')

# %%
repetidos_total_2[repetidos_total_2["Sex"]=="W"]
# Out:
# Empty DataFrame
# Columns: [Name, Sex, Age, Height, Weight, Team, NOC, Year, City, Sport, Event, Medal]
# Index: []

# %%
repetidos_total_2.to_csv("repetidos_total_2.csv",index=False)

# %% [markdown]
# ---
# ---
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode, iplot, plot

# %%
df_filt_height= repetidos_total_2[(repetidos_total_2["Height"] != 0)]
df_count_height= df_filt_height.groupby("Year")[["Height"]].count()

# %%
df_count_height
# Out:
#       Height
# Year
# 1896      46
# 1900     116
# 1904     213
# 1906     257
# 1908     475
# 1912     721
# 1920     767
# 1924     885
# 1928     853
# 1932    1017
# 1936    1056
# 1948    1053
# 1952    2038
# 1956    2342
# 1960    7738
# 1964    7430
# 1968    8493
# 1972   10018
# 1976    8283
# 1980    6961
# 1984    9032
# 1988   11719
# 1992   10453
# 1996   11909
# 2000   13698
# 2004   13407
# 2008   13451
# 2012   12752
# 2016   13512
# 2021    4717

# %%
edad_tocar=repetidos_total_2

# %%
edad_No_NaN=edad_tocar.groupby("Year")["Age"].count()
edad_Totales=edad_tocar.groupby("Year")["Year"].count()
porcentaje=edad_No_NaN/edad_Totales*100
resultados=pd.DataFrame({"alturas_No_NaN":edad_No_NaN,
                         "alturas_Totales":edad_Totales,
                         "Porcentaje":porcentaje})
resultados
# Out:
#       alturas_No_NaN  alturas_Totales  Porcentaje
# Year
# 1896             217              380   57.105263
# 1900            1146             1936   59.194215
# 1904            1027             1301   78.939277
# 1906             990             1733   57.126370
# 1908            2452             3101   79.071267
# 1912            3884             4040   96.138614
# 1920            3447             4292   80.312209
# 1924            4148             5233   79.266195
# 1928            4119             4992   82.512019
# 1932            2662             2969   89.659818
# 1936            6304             6506   96.895174
# 1948            5233             6405   81.701795
# 1952            7993             8270   96.650544
# 1956            4514             5127   88.043690
# 1960            7906             8119   97.376524
# 1964            7659             7702   99.441703
# 1968            8489             8588   98.847229
# 1972           10211            10304   99.097438
# ...

# %%
alturas_tocar[(alturas_tocar["Height"].notna())&(alturas_tocar["Year"]==2021)].groupby("Sport").size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20084\767894933.py in <module>
# ----> 1 alturas_tocar[(alturas_tocar["Height"].notna())&(alturas_tocar["Year"]==2021)].groupby("Sport").size()
#
# NameError: name 'alturas_tocar' is not defined

# %%
alturas_tocar[(alturas_tocar["Year"]==2021)].groupby("Sport")["Height"].size()
# Out:
# Sport
# 3x3 Basketball           64
# Archery                 132
# Athletics              2073
# Badminton               175
# Baseball                147
# Basketball              287
# Beach Volleyball         96
# Boxing                  291
# Canoeing                342
# Cycling                 575
# Diving                  147
# Equestrianism           239
# Fencing                 273
# Football                588
# Golf                    120
# Gymnastics              248
# Handball                363
# Hockey                  416
# Judo                    413
# Karate                   81
# Modern Pentathlon        66
# Rhythmic Gymnastics      96
# Rowing                  511
# Rugby Sevens            315
# Sailing                 349
# Shooting                369
# Skateboarding            82
# Softball                 90
# Sport Climbing           39
# Surfing                  40
# Swimming               1123
# Table Tennis            181
# Taekwondo               129
# ...
